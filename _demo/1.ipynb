# %%
from arty import filter
import core
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (10, 10)

# %%
img = (plt.imread('images/img.png') * 255).astype(int)
plt.imshow(img)
plt.show()

# %%
# dx, dy = artypy[core].edge.gradientX(img), artypy[core].edge.gradientY(img)
import cv2
from core.edge.gradient import Gradient
import numpy as np

image = img.astype(np.uint8)
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gradient = Gradient(image)
dx, dy = gradient.grad_x, gradient.grad_y

edges = gradient.gradient
angles = core.angle.gradient_truth(dx, dy)
lines = core.filter.lines(img, angles, edges)

# lines = filter.lines(img)

plt.imshow(lines)
plt.show()

# %%
# blur = artypy[core].filter.blur.gauss(img)
# dx, dy = artypy[core].edge.gradientX(blur), artypy[core].edge.gradientY(blur)
# edges = artypy[core].edge.gradient(blur)
# angles = artypy[core].angle.gradient_truth(dx, dy)
# lines_blur = artypy[core].filter.lines(blur, angles, edges)

lines_blur = filter.lines(img, True)

plt.imshow(lines_blur)
plt.show()

# %%
# noised = artypy[core].filter.noise(blur)
# lines_noise = artypy[core].filter.lines(noised, angles, edges)

lines_noise = filter.lines(img, True, True)

plt.imshow(lines_noise)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 4
#       1 # noised = core.filter.noise(blur)
#       2 # lines_noise = core.filter.lines(noised, angles, edges)
# ----> 4 lines_noise = filter.lines(img, True, True)
#       6 plt.imshow(lines_noise)
#       7 plt.show()
#
# File ~\PycharmProjects\arty\arty\filter\_lines.py:12, in lines(image, to_blur, to_noise)
#       9 if to_noise:
#      10     image = core.filter.noise(image)
# ---> 12 gradient = Gradient(image)
#      13 dx, dy = gradient.grad_x, gradient.grad_y
#      14 edges = gradient.gradient
#
# File ~\PycharmProjects\arty\core\edge\gradient.py:24, in Gradient.__init__(self, image, type, type_smoothing, radius, smoothing_iterations)
#      22     gray_image = image
#      23 elif len(image.shape) == 3:
# ---> 24     gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
#      25 else:
# ...
